# %% [markdown]
# # Huygens MTF

# %%
from optiland.mtf import HuygensMTF
from optiland.samples.objectives import CookeTriplet

# %%
lens = CookeTriplet()
_ = lens.draw()

# %%
mtf = HuygensMTF(
    lens,
    fields="all",
    wavelength="primary",
    num_rays=128,
    image_size=256,
    max_freq="cutoff"
)
_ = mtf.view()
