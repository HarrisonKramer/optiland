# %% [markdown]
# # MTF versus Field

# %%
from optiland.analysis import MTFvsField
from optiland.samples.objectives import CookeTriplet

# %%
lens = CookeTriplet()

# %%
_ = lens.draw()

# %%
rms_vs_field = MTFvsField(lens, frequencies=[10.0, 20.0, 30.0], num_rays=64, wavelengths="all")
_ = rms_vs_field.view()
