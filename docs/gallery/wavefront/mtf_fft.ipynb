# %% [markdown]
# # FFT MTF

# %%
from optiland.mtf import FFTMTF
from optiland.samples.eyepieces import EyepieceErfle

# %%
lens = EyepieceErfle()
lens.draw()

# %%
fft_mtf = FFTMTF(lens)
fft_mtf.view()
