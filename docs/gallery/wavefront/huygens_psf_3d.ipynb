# %% [markdown]
# # Huygens PSF - 3D

# %%
from optiland.psf import HuygensPSF
from optiland.samples.objectives import DoubleGauss

# %%
lens = DoubleGauss()
lens.draw()
# Out:
# (<Figure size 1000x400 with 1 Axes>, <Axes: xlabel='Z [mm]', ylabel='Y [mm]'>)

# %%
psf = HuygensPSF(lens, field=(0, 0.0), wavelength=0.55)
psf.view(projection="3d", num_points=128)
# Out:
# (<Figure size 700x550 with 2 Axes>,
#  <Axes3D: title={'center': 'ScalarHuygens PSF'}, xlabel='X (µm)', ylabel='Y (µm)', zlabel='Relative Intensity (%)'>)
