# %% [markdown]
# # Ray Aberration Fan

# %%
from optiland.analysis import RayFan
from optiland.samples.objectives import HeliarLens

# %%
lens = HeliarLens()

# %%
lens.draw()

# %%
ray_fan = RayFan(lens, fields=[(0, 1)])
ray_fan.view()

# %%
ray_fan = RayFan(lens)  # plots all fields by default
ray_fan.view()
