# %% [markdown]
# # RMS Wavefront Error versus Field

# %%
from optiland.analysis import RmsWavefrontErrorVsField
from optiland.samples.objectives import LensWithFieldCorrector

# %%
lens = LensWithFieldCorrector()

# %%
lens.draw()

# %%
rms_vs_field = RmsWavefrontErrorVsField(lens, num_fields=64)
rms_vs_field.view()
