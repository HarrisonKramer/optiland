# %% [markdown]
# # RMS Spot Size versus Field

# %%
from optiland.analysis import RmsSpotSizeVsField
from optiland.samples.objectives import TessarLens

# %%
lens = TessarLens()

# %%
lens.draw()

# %%
rms_vs_field = RmsSpotSizeVsField(lens)
rms_vs_field.view()
