# %% [markdown]
# # Y-Ybar

# %%
from optiland.analysis import YYbar
from optiland.samples.objectives import PetzvalLens

# %%
lens = PetzvalLens()

# %%
lens.draw()

# %%
yybar = YYbar(lens)
yybar.view()
